# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_file = Path("./Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_file, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna()
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_file = Path('./Resources/algo_returns.csv')
algo_df = pd.read_csv(algo_file, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_df.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# 2014-06-04 -0.001838       NaN
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna()
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_df.tail(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2019-04-17 -0.010301 -0.005228
# 2019-04-18 -0.000588 -0.001229
# 2019-04-22  0.000677 -0.001936
# 2019-04-23  0.004969  0.009622
# 2019-04-24  0.001095  0.000399
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_file = Path('./Resources/sp500_history.csv')
sp500_df = pd.read_csv(sp500_file, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
print(sp500_df.dtypes)
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df["Close"] = sp500_df["Close"].str.replace('$', '', regex=False)
sp500_df["Close"] = sp500_df["Close"].astype(float)

sp500_df = sp500_df.sort_index() 

sp500_df.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns

# %%
# Calculate daily returns
sp500_daily_returns = sp500_df.pct_change()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_daily_returns.isnull().sum()
sp500_daily_returns = sp500_daily_returns.dropna()
sp500_daily_returns
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.columns = ['sp500']
sp500_daily_returns
# Out:
#                sp500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
compare_data = pd.concat([whale_df,algo_df ,sp500_daily_returns], axis=1, join="inner")
compare_data.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
# 2015-03-16                   0.007901            0.003583
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
compare_data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
culmulative_returns = (1 + compare_data).cumprod() - 1
# Plot cumulative returns
culmulative_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
plt = compare_data.boxplot()
short_labels = ['SOROS','PAULSON','TIGER','BERKSHIRE', 'ALGO1', 'ALGO2', 'SP500']
plt.set_xticklabels(short_labels)
# Out:
# [Text(1, 0, 'SOROS'),
#  Text(2, 0, 'PAULSON'),
#  Text(3, 0, 'TIGER'),
#  Text(4, 0, 'BERKSHIRE'),
#  Text(5, 0, 'ALGO1'),
#  Text(6, 0, 'ALGO2'),
#  Text(7, 0, 'SP500')]

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
compare_data.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# sp500                          0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_daily_returns.std()
# Out:
# sp500    0.008111
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P
# * TIGER GLOBAL MANAGEMENT LLC    0.010894
# * BERKSHIRE HATHAWAY INC         0.012919

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
volatility = compare_data.std() * np.sqrt(252)
volatility = volatility.sort_values()
volatility
# Out:
# PAULSON & CO.INC.              0.111488
# Algo 1                         0.120967
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 2                         0.132430
# sp500                          0.135786
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
compare_data.rolling(window=21).std().plot()
# Plot the rolling standard deviation
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = compare_data.corr()
# Display de correlation matrix
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
# Change rolling covarience 
covariance = compare_data['Algo 2'].rolling(window=21).cov(compare_data['sp500'])

# Calculate variance of S&P 500
variance = compare_data['sp500'].rolling(window=21).var()
# Computing beta

# Plot beta trend
algo_2_beta = covariance / variance
algo_2_beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
compare_data.ewm(halflife=21).std()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-16                   0.007632            0.006846
# 2019-04-17                   0.007547            0.006846
# 2019-04-18                   0.007424            0.006737
# 2019-04-22                   0.007336            0.006764
# 2019-04-23                   0.007294            0.006682
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (compare_data.mean() * 252) / (compare_data.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# sp500                          0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
ax = sharpe_ratios.plot(kind='bar',figsize=(5,3))
ax.set_xticklabels(short_labels)
# Out:
# [Text(0, 0, 'SOROS'),
#  Text(1, 0, 'PAULSON'),
#  Text(2, 0, 'TIGER'),
#  Text(3, 0, 'BERKSHIRE'),
#  Text(4, 0, 'ALGO1'),
#  Text(5, 0, 'ALGO2'),
#  Text(6, 0, 'SP500')]

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Acording to the analysis, is a clear the algorithmic strategies outperform the whales portafolios, when we compare against the SP500 the second algorithmic stratagy underperform but the first algorithmic stratagy outperform all of the others.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
tsla_file = Path("./Resources/tsla.csv")
tsla = pd.read_csv(tsla_file, infer_datetime_format=True, parse_dates=True, index_col="Date")
tsla
# Out:
#             Close
# Date
# 2015-01-02  14.62
# 2015-01-05  14.01
# 2015-01-06  14.09
# 2015-01-07  14.06
# 2015-01-08  14.04
# ...           ...
# 2019-12-23  27.95
# 2019-12-24  28.35
# 2019-12-26  28.73
# 2019-12-27  28.69
# 2019-12-30  27.65
#
# [1257 rows x 1 columns]

# %%
# Reading data from 2nd stock
amzn_file = Path("./Resources/amzn.csv")
amzn = pd.read_csv(amzn_file, infer_datetime_format=True, parse_dates=True, index_col="Date")
amzn.head()
# Out:
#             Close
# Date
# 2015-01-02  15.43
# 2015-01-05  15.11
# 2015-01-06  14.76
# 2015-01-07  14.92
# 2015-01-08  15.02

# %%
# Reading data from 3rd stock
pypl_file = Path("./Resources/pypl.csv")
pypl = pd.read_csv(pypl_file,  infer_datetime_format=True, parse_dates=True, index_col="Date")
pypl.head()
# Out:
#             Close
# Date
# 2015-07-06  36.71
# 2015-07-07  36.62
# 2015-07-08  34.70
# 2015-07-09  34.50
# 2015-07-10  34.69

# %%
# Combine all stocks in a single DataFrame
tech = pd.concat([pypl, tsla, amzn], axis=1, join="inner")
tech.columns = ["pypl", "tsla", "amzn"]
tech.head()
# Out:
#              pypl   tsla   amzn
# Date
# 2015-07-06  36.71  18.65  21.80
# 2015-07-07  36.62  17.86  21.84
# 2015-07-08  34.70  17.00  21.49
# 2015-07-09  34.50  17.19  21.72
# 2015-07-10  34.69  17.28  22.18

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns
tech = tech.pct_change()

# Drop NAs
tech.isnull().sum()
tech = tech.dropna()

# Display sample data
tech.head()
# Out:
#                 pypl      tsla      amzn
# Date
# 2015-07-07 -0.002452 -0.042359  0.001835
# 2015-07-08 -0.052430 -0.048152 -0.016026
# 2015-07-09 -0.005764  0.011176  0.010703
# 2015-07-10  0.005507  0.005236  0.021179
# 2015-07-13  0.060248  0.011574  0.027051

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
tech_portafolio = tech.dot(weights)

# Display sample data
tech_portafolio.head()

tech_portafolio.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
tech_compare = pd.concat([tech_portafolio, compare_data], axis=1, join="inner")
short_labels.insert(0, "TECH")
tech_compare.columns = short_labels
tech_compare.head()
# Out:
#                 TECH     SOROS   PAULSON     TIGER  BERKSHIRE     ALGO1  \
# Date
# 2015-07-07 -0.014325  0.000597  0.003962  0.004652  -0.007634 -0.004611
# 2015-07-08 -0.038869 -0.017211 -0.007654 -0.014788  -0.011737 -0.013853
# 2015-07-09  0.005372  0.007472  0.003887  0.000441   0.017670  0.014090
# 2015-07-10  0.010640  0.008969  0.003589  0.013605   0.007015  0.003362
# 2015-07-13  0.032958  0.007946  0.001149  0.008658   0.010178  0.004215
#
#                ALGO2     SP500
# Date
# 2015-07-07 -0.002519  0.006081
# 2015-07-08 -0.015528 -0.016653
# 2015-07-09  0.003624  0.002262
# 2015-07-10  0.014381  0.012338
# 2015-07-13  0.008575  0.011066

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
tech_compare = tech_compare.dropna()
tech_compare.isnull().sum()
# Out:
# TECH         0
# SOROS        0
# PAULSON      0
# TIGER        0
# BERKSHIRE    0
# ALGO1        0
# ALGO2        0
# SP500        0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
tech_compare.std()
# Out:
# TECH         0.017029
# SOROS        0.008168
# PAULSON      0.007321
# TIGER        0.010443
# BERKSHIRE    0.013550
# ALGO1        0.007922
# ALGO2        0.008624
# SP500        0.008826
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
tech_compare.ewm(halflife=21).std().plot()
# Plot rolling standard deviation
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
tech_correlation = tech_compare.corr()
tech_correlation
# Out:
#                TECH     SOROS   PAULSON     TIGER  BERKSHIRE     ALGO1  \
# TECH       1.000000  0.617442  0.457151  0.451304   0.679189  0.244027
# SOROS      0.617442  1.000000  0.703110  0.603701   0.758859  0.339292
# PAULSON    0.457151  0.703110  1.000000  0.470639   0.550320  0.288690
# TIGER      0.451304  0.603701  0.470639  1.000000   0.478827  0.191723
# BERKSHIRE  0.679189  0.758859  0.550320  0.478827   1.000000  0.303135
# ALGO1      0.244027  0.339292  0.288690  0.191723   0.303135  1.000000
# ALGO2      0.580213  0.831616  0.683231  0.559927   0.687621  0.310834
# SP500      0.681770  0.842640  0.677202  0.685803   0.754264  0.293218
#
#               ALGO2     SP500
# TECH       0.580213  0.681770
# SOROS      0.831616  0.842640
# PAULSON    0.683231  0.677202
# TIGER      0.559927  0.685803
# BERKSHIRE  0.687621  0.754264
# ALGO1      0.310834  0.293218
# ALGO2      1.000000  0.858849
# SP500      0.858849  1.000000

# %%
sns.heatmap(tech_correlation)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
tech_portafolio_covariance = tech_portafolio.rolling(window=60).cov(compare_data['sp500'])

#change variance to window 60
tech_rolling_beta = tech_portafolio_covariance / variance
ax = tech_rolling_beta.plot(figsize=(20,10), title="Rolling 60-days, AMZN, PYPL, TSLA")

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# some handy functions to use along widgets
from IPython.display import display, Markdown, clear_output
# widget packages
import ipywidgets as widgets
# defining some widgets
text = widgets.Text(
       value='My Text',
       description='Title', )
calendar = widgets.DatePicker(
           description='Select Date')
slider = widgets.FloatSlider(
         value=1,
         min=0,
         max=10.0,
         step=0.1,)
menu = widgets.Dropdown(
       options=['red', 'blue', 'green'],
       value='red',
       description='Color:')
checkbox = widgets.Checkbox(
           description='Check to invert',)

# %%
# Calculate Annualized Sharpe Ratios

# %%
# Visualize the sharpe ratios as a bar plot

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
